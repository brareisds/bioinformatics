# %% [markdown]
# # Busca por genes no KEGG
#
# Buscou-se os organismos no KEGG através deste [link](https://www.kegg.jp/kegg/tables/br08606.html) e buscou-se pelo gene "16S rRNA" ao abrir a página de cada organismo. Isso leva a uma lista de genes. Abriu-se então o primeiro gene da lista, com exceções marcadas por asterisco. Abriu-se o NCBI-ProteinID contido na descrição, e na página do NBCI em "Related Informatio" pode ou não haver uma aba chamada "Gene".
#
# OBS: Na própria página do gene no KEGG há a sequência de nucleotídeos no final, que poderia ser usada alternativamente à busca do gene no NCBI.
#
# | Organismo | Ambiente | Código KEGG | Lista de 16S rRNA | NCBI-ProteinID do Primeiro da Lista | Gene ID no NCBI |
# |---|---|---|---|---|---|
# | *T. ruber* | Hipertermófilo | trd | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=trd&mode=bfind&keywords=16s+rrna) | [AHE95369](https://www.ncbi.nlm.nih.gov/protein/AHE95369) | |
# | *T. maritima* | Hipertermófilo | tma | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=tma&mode=bfind&keywords=16s+rrna)| [AAD35789](https://www.ncbi.nlm.nih.gov/protein/AAD35789)** | |
# | *P. furiosus* | Hipertermófilo | pfu | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=pfu&mode=bfind&keywords=16s+rrna) | [AAL81987](https://www.ncbi.nlm.nih.gov/protein/AAL81987)** | [1469742](https://www.ncbi.nlm.nih.gov/gene/1469742) |
# | *T. litoralis* | Hipertermófilo | tlt | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=tlt&mode=bfind&keywords=16s+rrna) | [EHR78097](https://www.ncbi.nlm.nih.gov/protein/EHR78097) | [16548623](https://www.ncbi.nlm.nih.gov/gene?LinkName=protein_gene&from_uid=374741677) |
# | *E. fergusonii* | Mesófilo | efe | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=efe&mode=bfind&keywords=16s+rrna)| [CAQ87648](https://www.ncbi.nlm.nih.gov/protein/CAQ87648) | |
# | *M. maripaludis* | Mesófilo | mmao | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=mmao&mode=bfind&keywords=16s+rrna) | [BAP6268](https://www.ncbi.nlm.nih.gov/protein/BAP62682)* | [37875082](https://www.ncbi.nlm.nih.gov/gene?LinkName=protein_gene&from_uid=693015102)|
# | *P. arcticus* | Psicrófilo | par | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=par&mode=bfind&keywords=16s+rrna) | [AAZ17898](https://www.ncbi.nlm.nih.gov/protein/AAZ17898) | |
# | *M. burtonii* | Psicrófilo | mbu | [link](https://www.kegg.jp/dbget-bin/www_bfind_sub?max_hit=1000&dbkey=mbu&mode=bfind&keywords=16s+rrna) | [ABE51849](https://www.ncbi.nlm.nih.gov/protein/ABE51849) | [3998646](https://www.ncbi.nlm.nih.gov/gene?LinkName=protein_gene&from_uid=91711922) |
#
# "*" segundo da lista
#
# "**" terceiro da lista
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# Ambientes
ambientes = {
    "T_ruber":       "hipertermofilo",
    "T_maritima":    "hipertermofilo",
    "P_furiosus":    "hipertermofilo",
    "T_litoralis":   "hipertermofilo",
    "E_fergusonii":  "mesofilo",
    "M_maripaludis": "mesofilo",
    "P_arcticus":    "psicrófilo",
    "M_burtonii":    "psicrófilo",
}
